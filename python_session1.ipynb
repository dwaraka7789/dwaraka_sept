# %%
a=10
b=20
a+b
# Out:
# 30

# %% [markdown]
# i learn python programming language

# %% [markdown]
# # python
# ## python
# ### Python

# %% [markdown]
# - today i am learning python
# - it is very interesting
# - i am understanding **platform**
#     - there are two modes
#     - To write the code, we have **code mode**
#     - to write the text, we hvae **markdown mode**

# %%
a=10
a
# Out:
# 10

# %%
b=20
b
# Out:
# 20

# %%
import time
time.sleep(15)
print('hello')
# Out:
# hello

# %%
a=input()
b=input()
a+b
# Out:
#  10 20
#  10
# '10 2010'

# %%
a=int(input())
b=int(input())
a+b
# Out:
#  10
#  20
# 30

# %%
a=int(input('Enter a first number'))
b=int(input('Enter a second number'))
print(f'the sum of {a} and {b} is :{a+b}')
# Out:
# Enter a first number 15
# Enter a second number 25
# the sum of 15 and 25 is :40

# %%
a=eval(input('Enter a first number'))
b=eval(input('Enter a second number'))
print(f'the sum of {a} and {b} is :{a+b}')
# Out:
# Enter a first number 10
# Enter a second number 200
# the sum of 10 and 200 is :210

# %%
name=input('Enter a name')
age=eval(input('enter age'))
city=input('enter city')
print(f' my name is {name}, i have {age} years old, i came from {city}')
# Out:
# Enter a name dwaraka
# enter age 10
# enter city hyd
#  my name is dwaraka, i have 10 years old, i came from hyd
