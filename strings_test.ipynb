# %%
str1='python'
type(str1)
len(str1)
min(str1)
reversed(str1)

# %%
reversed(str1)

# %%
print(reversed(str1))

# %%
min(str1)
# Out:
# 'h'

# %%
len(str1)
# Out:
# 6

# %%
'p' > 'P'
# Out:
# True

# %%
sum(str1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sum(str1)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
list1=[0]
for i in list1:
 print(i)
# Out:
# 0
